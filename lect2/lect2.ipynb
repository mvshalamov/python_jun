# %%
l = "какая-то строка"

# %%
dir(l)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
# ...

# %%
len(l)
# Out:
# 15

# %%
otr = """
Кутузов, сопутствуемый своими адъютантами, поехал шагом за карабинерами. 
Проехав с полверсты в хвосте колонны, он остановился у одинокого заброшенного дома (вероятно, бывшего трактира) подле разветвления двух дорог. Обе дороги спускались под гору, и по обеим шли войска.
Туман начинал расходиться, и неопределенно, верстах в двух расстояния, виднелись уже неприятельские войска на противоположных возвышенностях. Налево внизу стрельба становилась слышнее. Кутузов остановился, разговаривая с австрийским генералом. Князь Андрей, стоя несколько позади, вглядывался в них и, желая попросить зрительную трубу у адъютанта, обратился к нему.
— Посмотрите, посмотрите, — говорил этот адъютант, глядя не на дальние войска, а вниз по горе перед собой. — Это французы!
Два генерала и адъютанты стали хвататься за трубу, вырывая ее один у другого. Все лица вдруг изменились, и на всех выразился ужас. Французов предполагали за две версты от нас, а они явились вдруг неожиданно перед нами.
— Это неприятель?.. Нет!.. Да, смотрите, он... наверное... Что ж это? — послышались голоса.
Князь Андрей простым глазом увидал внизу направо поднимавшуюся навстречу апшеронцам густую колонну французов, не дальше пятисот шагов от того места, где стоял Кутузов.
"""

# %%
otr.count("Кутузов")
# Out:
# 3

# %%
otr_new = otr.replace('Нет', 'Да')

# %%
otr_new
# Out:
# '\nКутузов, сопутствуемый своими адъютантами, поехал шагом за карабинерами. \nПроехав с полверсты в хвосте колонны, он остановился у одинокого заброшенного дома (вероятно, бывшего трактира) подле разветвления двух дорог. Обе дороги спускались под гору, и по обеим шли войска.\nТуман начинал расходиться, и неопределенно, верстах в двух расстояния, виднелись уже неприятельские войска на противоположных возвышенностях. Налево внизу стрельба становилась слышнее. Кутузов остановился, разговаривая с австрийским генералом. Князь Андрей, стоя несколько позади, вглядывался в них и, желая попросить зрительную трубу у адъютанта, обратился к нему.\n— Посмотрите, посмотрите, — говорил этот адъютант, глядя не на дальние войска, а вниз по горе перед собой. — Это французы!\nДва генерала и адъютанты стали хвататься за трубу, вырывая ее один у другого. Все лица вдруг изменились, и на всех выразился ужас. Французов предполагали за две версты от нас, а они явились вдруг неожиданно перед нами.\n— Это непр
# ...

# %%
otr.split('.')
# Out:
# ['\nКутузов, сопутствуемый своими адъютантами, поехал шагом за карабинерами',
#  ' \nПроехав с полверсты в хвосте колонны, он остановился у одинокого заброшенного дома (вероятно, бывшего трактира) подле разветвления двух дорог',
#  ' Обе дороги спускались под гору, и по обеим шли войска',
#  '\nТуман начинал расходиться, и неопределенно, верстах в двух расстояния, виднелись уже неприятельские войска на противоположных возвышенностях',
#  ' Налево внизу стрельба становилась слышнее',
#  ' Кутузов остановился, разговаривая с австрийским генералом',
#  ' Князь Андрей, стоя несколько позади, вглядывался в них и, желая попросить зрительную трубу у адъютанта, обратился к нему',
#  '\n— Посмотрите, посмотрите, — говорил этот адъютант, глядя не на дальние войска, а вниз по горе перед собой',
#  ' — Это французы!\nДва генерала и адъютанты стали хвататься за трубу, вырывая ее один у другого',
#  ' Все лица вдруг изменились, и на всех выразился ужас',
# ...

# %%
len(otr.split('.'))
# Out:
# 24

# %%
test_split = otr.capitalize().replace('.', ' ').replace('\n', '')
list_words = test_split.split(' ')
list_words
# Out:
# ['кутузов,',
#  'сопутствуемый',
#  'своими',
#  'адъютантами,',
#  'поехал',
#  'шагом',
#  'за',
#  'карабинерами',
#  '',
#  'проехав',
#  'с',
#  'полверсты',
#  'в',
#  'хвосте',
#  'колонны,',
#  'он',
#  'остановился',
#  'у',
#  'одинокого',
#  'заброшенного',
#  'дома',
#  '(вероятно,',
#  'бывшего',
#  'трактира)',
#  'подле',
#  'разветвления',
#  'двух',
#  'дорог',
#  '',
#  'обе',
#  'дороги',
#  'спускались',
#  'под',
#  'гору,',
#  'и',
#  'по',
#  'обеим',
#  'шли',
#  'войска',
#  'туман',
#  'начинал',
#  'расходиться,',
#  'и',
#  'неопределенно,',
#  'верстах',
#  'в',
#  'двух',
#  'расстояния,',
#  'виднелись',
#  'уже',
#  'неприятельские',
#  'войска',
#  'на',
#  'противоположных',
#  'возвышенностях',
#  '',
#  'налево',
#  'внизу',
#  'стрельба',
#  'становилась',
#  'слышнее',
#  '',
#  'кутузов',
#  'остановился,',
#  'разговаривая',
#  'с',
#  'австрийским',
#  'генералом',
#  '',
#  'князь',
#  'андрей,',
#  'стоя',
#  'несколько',
#  'позади,',
# ...

# %%
len(list_words)
# Out:
# 194

# %%
list_words.count('кутузов')
# Out:
# 2

# %%
# используем регулярки в жизни, но пока рано
symb = [',', '!', '(', ')', '—', '?']
for i, word in enumerate(list_words):
    for s in symb:
        if s in word:
            list_words[i] = word.replace(s, '')

# %%
3 in [1,2]
# Out:
# False

# %%
# [[word.replace(word, s) for s in symb] for word in words]

# %%
list_words
# Out:
# ['кутузов',
#  'сопутствуемый',
#  'своими',
#  'адъютантами',
#  'поехал',
#  'шагом',
#  'за',
#  'карабинерами',
#  '',
#  'проехав',
#  'с',
#  'полверсты',
#  'в',
#  'хвосте',
#  'колонны',
#  'он',
#  'остановился',
#  'у',
#  'одинокого',
#  'заброшенного',
#  'дома',
#  'вероятно',
#  'бывшего',
#  'трактира',
#  'подле',
#  'разветвления',
#  'двух',
#  'дорог',
#  '',
#  'обе',
#  'дороги',
#  'спускались',
#  'под',
#  'гору',
#  'и',
#  'по',
#  'обеим',
#  'шли',
#  'войска',
#  'туман',
#  'начинал',
#  'расходиться',
#  'и',
#  'неопределенно',
#  'верстах',
#  'в',
#  'двух',
#  'расстояния',
#  'виднелись',
#  'уже',
#  'неприятельские',
#  'войска',
#  'на',
#  'противоположных',
#  'возвышенностях',
#  '',
#  'налево',
#  'внизу',
#  'стрельба',
#  'становилась',
#  'слышнее',
#  '',
#  'кутузов',
#  'остановился',
#  'разговаривая',
#  'с',
#  'австрийским',
#  'генералом',
#  '',
#  'князь',
#  'андрей',
#  'стоя',
#  'несколько',
#  'позади',
#  'вглядывался',
# ...

# %%
' '.join(list_words)
# Out:
# 'кутузов сопутствуемый своими адъютантами поехал шагом за карабинерами  проехав с полверсты в хвосте колонны он остановился у одинокого заброшенного дома вероятно бывшего трактира подле разветвления двух дорог  обе дороги спускались под гору и по обеим шли войска туман начинал расходиться и неопределенно верстах в двух расстояния виднелись уже неприятельские войска на противоположных возвышенностях  налево внизу стрельба становилась слышнее  кутузов остановился разговаривая с австрийским генералом  князь андрей стоя несколько позади вглядывался в них и желая попросить зрительную трубу у адъютанта обратился к нему  посмотрите посмотрите  говорил этот адъютант глядя не на дальние войска а вниз по горе перед собой   это французыдва генерала и адъютанты стали хвататься за трубу вырывая ее один у другого  все лица вдруг изменились и на всех выразился ужас  французов предполагали за две версты от нас а они явились вдруг неожиданно перед нами  это неприятель   нет   да смотрите он    наверн
# ...

# %%
list_words_without_empty = [word for word in list_words if word]

# %%
list_words_without_empty
# Out:
# ['кутузов',
#  'сопутствуемый',
#  'своими',
#  'адъютантами',
#  'поехал',
#  'шагом',
#  'за',
#  'карабинерами',
#  'проехав',
#  'с',
#  'полверсты',
#  'в',
#  'хвосте',
#  'колонны',
#  'он',
#  'остановился',
#  'у',
#  'одинокого',
#  'заброшенного',
#  'дома',
#  'вероятно',
#  'бывшего',
#  'трактира',
#  'подле',
#  'разветвления',
#  'двух',
#  'дорог',
#  'обе',
#  'дороги',
#  'спускались',
#  'под',
#  'гору',
#  'и',
#  'по',
#  'обеим',
#  'шли',
#  'войска',
#  'туман',
#  'начинал',
#  'расходиться',
#  'и',
#  'неопределенно',
#  'верстах',
#  'в',
#  'двух',
#  'расстояния',
#  'виднелись',
#  'уже',
#  'неприятельские',
#  'войска',
#  'на',
#  'противоположных',
#  'возвышенностях',
#  'налево',
#  'внизу',
#  'стрельба',
#  'становилась',
#  'слышнее',
#  'кутузов',
#  'остановился',
#  'разговаривая',
#  'с',
#  'австрийским',
#  'генералом',
#  'князь',
#  'андрей',
#  'стоя',
#  'несколько',
#  'позади',
#  'вглядывался',
#  'в',
#  'них',
#  'и',
# ...

# %%
from collections import Counter

# %%
counter = Counter(list_words_without_empty)

# %%
counter.most_common(5)
# Out:
# [('и', 5), ('кутузов', 3), ('за', 3), ('в', 3), ('у', 3)]

# %%
# получаем уникальные слова в тексте
unique_words = set(list_words_without_empty)

# %%
unique_words
# Out:
# {'а',
#  'австрийским',
#  'адъютант',
#  'адъютанта',
#  'адъютантами',
#  'адъютанты',
#  'андрей',
#  'апшеронцам',
#  'бывшего',
#  'в',
#  'вглядывался',
#  'вдруг',
#  'вероятно',
#  'верстах',
#  'версты',
#  'виднелись',
#  'вниз',
#  'внизу',
#  'возвышенностях',
#  'войска',
#  'все',
#  'всех',
#  'выразился',
#  'вырывая',
#  'где',
#  'генерала',
#  'генералом',
#  'глазом',
#  'глядя',
#  'говорил',
#  'голоса',
#  'горе',
#  'гору',
#  'густую',
#  'да',
#  'дальние',
#  'дальше',
#  'две',
#  'двух',
#  'дома',
#  'дорог',
#  'дороги',
#  'другого',
#  'ее',
#  'ж',
#  'желая',
#  'за',
#  'заброшенного',
#  'зрительную',
#  'и',
#  'изменились',
#  'к',
#  'карабинерами',
#  'князь',
#  'колонну',
#  'колонны',
#  'кутузов',
#  'лица',
#  'места',
#  'на',
#  'наверное',
#  'навстречу',
#  'налево',
#  'нами',
#  'направо',
#  'нас',
#  'начинал',
#  'не',
#  'нему',
#  'неожиданно',
#  'неопределенно',
#  'неприятель',
#  'неприятельские',
#  'несколько',
#  'нет',
# ...

# %%
unique_words - {'этот', 'это', 'явились'}
# Out:
# {'а',
#  'австрийским',
#  'адъютант',
#  'адъютанта',
#  'адъютантами',
#  'адъютанты',
#  'андрей',
#  'апшеронцам',
#  'бывшего',
#  'в',
#  'вглядывался',
#  'вдруг',
#  'вероятно',
#  'верстах',
#  'версты',
#  'виднелись',
#  'вниз',
#  'внизу',
#  'возвышенностях',
#  'войска',
#  'все',
#  'всех',
#  'выразился',
#  'вырывая',
#  'где',
#  'генерала',
#  'генералом',
#  'глазом',
#  'глядя',
#  'говорил',
#  'голоса',
#  'горе',
#  'гору',
#  'густую',
#  'да',
#  'дальние',
#  'дальше',
#  'две',
#  'двух',
#  'дома',
#  'дорог',
#  'дороги',
#  'другого',
#  'ее',
#  'ж',
#  'желая',
#  'за',
#  'заброшенного',
#  'зрительную',
#  'и',
#  'изменились',
#  'к',
#  'карабинерами',
#  'князь',
#  'колонну',
#  'колонны',
#  'кутузов',
#  'лица',
#  'места',
#  'на',
#  'наверное',
#  'навстречу',
#  'налево',
#  'нами',
#  'направо',
#  'нас',
#  'начинал',
#  'не',
#  'нему',
#  'неожиданно',
#  'неопределенно',
#  'неприятель',
#  'неприятельские',
#  'несколько',
#  'нет',
# ...

# %%
counter['того']
# Out:
# 1

# %%
list_words.append('1')
half1 = list_words[:len(list_words)//2] 
half2 = list_words[len(list_words)//2:]

# %%
print(len(half1))
print(len(half2))
print(len(list_words))
# Out:
# 97
# 98
# 195

# %%
half1
# Out:
# ['кутузов',
#  'сопутствуемый',
#  'своими',
#  'адъютантами',
#  'поехал',
#  'шагом',
#  'за',
#  'карабинерами',
#  '',
#  'проехав',
#  'с',
#  'полверсты',
#  'в',
#  'хвосте',
#  'колонны',
#  'он',
#  'остановился',
#  'у',
#  'одинокого',
#  'заброшенного',
#  'дома',
#  'вероятно',
#  'бывшего',
#  'трактира',
#  'подле',
#  'разветвления',
#  'двух',
#  'дорог',
#  '',
#  'обе',
#  'дороги',
#  'спускались',
#  'под',
#  'гору',
#  'и',
#  'по',
#  'обеим',
#  'шли',
#  'войска',
#  'туман',
#  'начинал',
#  'расходиться',
#  'и',
#  'неопределенно',
#  'верстах',
#  'в',
#  'двух',
#  'расстояния',
#  'виднелись',
#  'уже',
#  'неприятельские',
#  'войска',
#  'на',
#  'противоположных',
#  'возвышенностях',
#  '',
#  'налево',
#  'внизу',
#  'стрельба',
#  'становилась',
#  'слышнее',
#  '',
#  'кутузов',
#  'остановился',
#  'разговаривая',
#  'с',
#  'австрийским',
#  'генералом',
#  '',
#  'князь',
#  'андрей',
#  'стоя',
#  'несколько',
#  'позади',
#  'вглядывался',
# ...

# %%
half2
# Out:
# ['дальние',
#  'войска',
#  'а',
#  'вниз',
#  'по',
#  'горе',
#  'перед',
#  'собой',
#  '',
#  '',
#  'это',
#  'французыдва',
#  'генерала',
#  'и',
#  'адъютанты',
#  'стали',
#  'хвататься',
#  'за',
#  'трубу',
#  'вырывая',
#  'ее',
#  'один',
#  'у',
#  'другого',
#  '',
#  'все',
#  'лица',
#  'вдруг',
#  'изменились',
#  'и',
#  'на',
#  'всех',
#  'выразился',
#  'ужас',
#  '',
#  'французов',
#  'предполагали',
#  'за',
#  'две',
#  'версты',
#  'от',
#  'нас',
#  'а',
#  'они',
#  'явились',
#  'вдруг',
#  'неожиданно',
#  'перед',
#  'нами',
#  '',
#  'это',
#  'неприятель',
#  '',
#  '',
#  'нет',
#  '',
#  '',
#  'да',
#  'смотрите',
#  'он',
#  '',
#  '',
#  '',
#  'наверное',
#  '',
#  '',
#  '',
#  'что',
#  'ж',
#  'это',
#  '',
#  'послышались',
#  'голоса',
#  'князь',
#  'андрей',
#  'простым',
#  'глазом',
#  'увидал',
#  'внизу',
#  'направо',
#  'поднимавшуюся',
#  'навстречу',
#  'апшеронцам',
#  'густую',
#  'колонну',
#  'французов',
#  'не',
# ...

# %%
half1 + half2
# Out:
# ['кутузов',
#  'сопутствуемый',
#  'своими',
#  'адъютантами',
#  'поехал',
#  'шагом',
#  'за',
#  'карабинерами',
#  '',
#  'проехав',
#  'с',
#  'полверсты',
#  'в',
#  'хвосте',
#  'колонны',
#  'он',
#  'остановился',
#  'у',
#  'одинокого',
#  'заброшенного',
#  'дома',
#  'вероятно',
#  'бывшего',
#  'трактира',
#  'подле',
#  'разветвления',
#  'двух',
#  'дорог',
#  '',
#  'обе',
#  'дороги',
#  'спускались',
#  'под',
#  'гору',
#  'и',
#  'по',
#  'обеим',
#  'шли',
#  'войска',
#  'туман',
#  'начинал',
#  'расходиться',
#  'и',
#  'неопределенно',
#  'верстах',
#  'в',
#  'двух',
#  'расстояния',
#  'виднелись',
#  'уже',
#  'неприятельские',
#  'войска',
#  'на',
#  'противоположных',
#  'возвышенностях',
#  '',
#  'налево',
#  'внизу',
#  'стрельба',
#  'становилась',
#  'слышнее',
#  '',
#  'кутузов',
#  'остановился',
#  'разговаривая',
#  'с',
#  'австрийским',
#  'генералом',
#  '',
#  'князь',
#  'андрей',
#  'стоя',
#  'несколько',
#  'позади',
#  'вглядывался',
# ...

# %%
len(half1 + half2)
# Out:
# 195

# %%
from collections import defaultdict


freq_word = defaultdict(float)
l = len(list_words_without_empty)
for k, v in counter.items():
    freq_word[k] = float(v)/l
freq_word

# %%
var = input()
# Out:
# ewrwerwer

# %%
type(var)
# Out:
# str

# %%
# многострочный ввод
lines = []
while True:
    line = input()
    if line:
        lines.append(line)
    else:
        break
text = '\n'.join(lines)
# Out:
# sdfsdf
# sdfsdfsd
# sdfsdf
# 324234
# sdfsdf

# %%
lines
# Out:
# ['sdfsdf', 'sdfsdfsd', 'sdfsdf', '324234', 'sdfsdf']

# %%
text1 = 'Text - %s:%s:%s'
text2 = 'Text - {}:{}:{}'
text3 = 'Text - {word1}:{word2}:{word3}'
text4 = 'Text - {1}:{0}:{2}'

print(text1 % (111,2,3))
print(text2.format("sdfsdf",2,3))
print(text3.format(word1 = 1, word2 = 2, word3 = 3))
print(text4.format(2,1,3))
# Out:
# Text - 111:2:3
# Text - sdfsdf:2:3
# Text - 1:2:3
# Text - 1:2:3

# %%
import os

tree = os.walk('/Users/maximshalamov/Desktop/work/python_jun/')

# %%
for i in tree:
    print(i)
